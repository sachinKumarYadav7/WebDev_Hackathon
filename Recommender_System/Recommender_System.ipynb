# %%
import numpy as np
import pandas as pd
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt


from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# %matplotlib inline

# %%
df = pd.read_json("UpdatedDatasetSOI .json")

# %%
df.head()
# Out:
#                                                title  \
# 0                         Introduction to Algorithms
# 1         Artificial Intelligence: A Modern Approach
# 2  Clean Code: A Handbook of Agile Software Craft...
# 3  Design Patterns: Elements of Reusable Object-O...
# 4  The Pragmatic Programmer: Your Journey to Mastery
#
#                                          description  \
# 0  Comprehensive guide to algorithms with detaile...
# 1  Fundamental concepts and techniques in AI, cov...
# 2  Principles and best practices for writing clea...
# 3  Classic book on design patterns for software d...
# 4  Practical advice for becoming a better program...
#
#                                               author                    genre  \
# 0  Thomas H. Cormen, Charles E. Leiserson, Ronald...               Algorithms
# 1                       Stuart Russell, Peter Norvig  Artificial Intelligence
# 2                                   Robert C. Martin     Software Engineering
# 3  Erich Gamma, Richard Helm, Ralph Johnson, John...     Software Engineering
# 4                          Andrew Hunt, David Thomas     Software Engineering
#
#          department  count             vendor  vendor_id  \
# 0  Computer Science      9  Indian Book Depot       1003
# 1  Computer Science     12        Kitab Mahal       1004
# 2  Computer Science     13  Indian Book Depot       1003
# 3  Computer Science      8       Amazon India       1006
# 4  Computer Science     10        Kitab Mahal       1004
#
#                   publisher  publisher_id
# 0           Lpringer Nature        234567
# 1  KarperMollins Publishers        345678
# 2          Mengage Learning        901234
# 3           Lpringer Nature        234567
# 4  JarperCollins Publishers        123456

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         120 non-null    object
#  1   description   120 non-null    object
#  2   author        120 non-null    object
#  3   genre         120 non-null    object
#  4   department    120 non-null    object
#  5   count         120 non-null    int64
#  6   vendor        120 non-null    object
#  7   vendor_id     120 non-null    int64
#  8   publisher     120 non-null    object
#  9   publisher_id  120 non-null    int64
# dtypes: int64(3), object(7)
# memory usage: 9.5+ KB

# %%
df['book_id'] = range(1, len(df) + 1)
df['book_id'] = df['book_id'].apply(lambda x: str(x).zfill(6))
df['book_id'] = df['book_id'].astype(int)

# %%
df.head()
# Out:
#                                                title  \
# 0                         Introduction to Algorithms
# 1         Artificial Intelligence: A Modern Approach
# 2  Clean Code: A Handbook of Agile Software Craft...
# 3  Design Patterns: Elements of Reusable Object-O...
# 4  The Pragmatic Programmer: Your Journey to Mastery
#
#                                          description  \
# 0  Comprehensive guide to algorithms with detaile...
# 1  Fundamental concepts and techniques in AI, cov...
# 2  Principles and best practices for writing clea...
# 3  Classic book on design patterns for software d...
# 4  Practical advice for becoming a better program...
#
#                                               author                    genre  \
# 0  Thomas H. Cormen, Charles E. Leiserson, Ronald...               Algorithms
# 1                       Stuart Russell, Peter Norvig  Artificial Intelligence
# 2                                   Robert C. Martin     Software Engineering
# 3  Erich Gamma, Richard Helm, Ralph Johnson, John...     Software Engineering
# 4                          Andrew Hunt, David Thomas     Software Engineering
#
#          department  count             vendor  vendor_id  \
# 0  Computer Science      9  Indian Book Depot       1003
# 1  Computer Science     12        Kitab Mahal       1004
# 2  Computer Science     13  Indian Book Depot       1003
# 3  Computer Science      8       Amazon India       1006
# 4  Computer Science     10        Kitab Mahal       1004
#
#                   publisher  publisher_id  book_id
# 0           Lpringer Nature        234567        1
# 1  KarperMollins Publishers        345678        2
# 2          Mengage Learning        901234        3
# 3           Lpringer Nature        234567        4
# 4  JarperCollins Publishers        123456        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         120 non-null    object
#  1   description   120 non-null    object
#  2   author        120 non-null    object
#  3   genre         120 non-null    object
#  4   department    120 non-null    object
#  5   count         120 non-null    int64
#  6   vendor        120 non-null    object
#  7   vendor_id     120 non-null    int64
#  8   publisher     120 non-null    object
#  9   publisher_id  120 non-null    int64
#  10  book_id       120 non-null    int64
# dtypes: int64(4), object(7)
# memory usage: 10.4+ KB

# %%
df_csv = pd.read_csv("datasetnew2.csv")

# %%
df_csv.head()
# Out:
#                                                title  \
# 0                         Introduction to Algorithms
# 1         Artificial Intelligence: A Modern Approach
# 2  Clean Code: A Handbook of Agile Software Craft...
# 3  Design Patterns: Elements of Reusable Object-O...
# 4  The Pragmatic Programmer: Your Journey to Mastery
#
#                                          description  \
# 0  Comprehensive guide to algorithms with detaile...
# 1  Fundamental concepts and techniques in AI, cov...
# 2  Principles and best practices for writing clea...
# 3  Classic book on design patterns for software d...
# 4  Practical advice for becoming a better program...
#
#                                               author                    genre  \
# 0  Thomas H. Cormen, Charles E. Leiserson, Ronald...               Algorithms
# 1                       Stuart Russell, Peter Norvig  Artificial Intelligence
# 2                                   Robert C. Martin     Software Engineering
# 3  Erich Gamma, Richard Helm, Ralph Johnson, John...     Software Engineering
# 4                          Andrew Hunt, David Thomas     Software Engineering
#
#          department  count             vendor  vendor_id  \
# 0  Computer Science      9  Indian Book Depot       1003
# 1  Computer Science     12        Kitab Mahal       1004
# 2  Computer Science     13  Indian Book Depot       1003
# 3  Computer Science      8       Amazon India       1006
# 4  Computer Science     10        Kitab Mahal       1004
#
#                   publisher  publisher_id
# 0           Lpringer Nature        234567
# 1  KarperMollins Publishers        345678
# 2          Mengage Learning        901234
# 3           Lpringer Nature        234567
# 4  JarperCollins Publishers        123456

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         120 non-null    object
#  1   description   120 non-null    object
#  2   author        120 non-null    object
#  3   genre         120 non-null    object
#  4   department    120 non-null    object
#  5   count         120 non-null    int64
#  6   vendor        120 non-null    object
#  7   vendor_id     120 non-null    int64
#  8   publisher     120 non-null    object
#  9   publisher_id  120 non-null    int64
# dtypes: int64(3), object(7)
# memory usage: 9.5+ KB

# %%
are_equal = df_csv.equals(df)
are_equal
# Out:
# False

# %%
df.columns
# Out:
# Index(['title', 'description', 'author', 'genre', 'department', 'count',
#        'vendor', 'vendor_id', 'publisher', 'publisher_id', 'book_id'],
#       dtype='object')

# %%
# Index(['title', 'author', 'genre', 'book_id'], dtype='object')
df['book_id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 115    116
# 116    117
# 117    118
# 118    119
# 119    120
# Name: book_id, Length: 120, dtype: int64

# %% [markdown]
# # Content-Based Filtering

# %% [markdown]
# recommends items similar to those a user has liked in the past

# %%
df['combined_features'] = df['title'] + ' ' + df['description'] + ' ' + df['author'] + ' ' + df['genre'] + ' ' + df['department']


tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])


cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)


def get_content_based_recommendations(title, cosine_sim=cosine_sim):
    idx = df[df['title'] == title].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:10]  
    book_indices = [i[0] for i in sim_scores]
    return df.iloc[book_indices][['title', 'author', 'genre']]
    

# print(get_content_based_recommendations('Introduction to Algorithms').tolist())
get_content_based_recommendations('Introduction to Algorithms')
# Out:
#                                                 title  \
# 19                                Algorithms Unlocked
# 7                     The Art of Computer Programming
# 9                                   Computer Networks
# 51  Digital Signal Processing: Principles, Algorit...
# 8   Structure and Interpretation of Computer Programs
# 23  Materials Science and Engineering: An Introduc...
# 4   The Pragmatic Programmer: Your Journey to Mastery
# 14     Computer Architecture: A Quantitative Approach
# 42                   Power System Analysis and Design
#
#                                                author  \
# 19                                   Thomas H. Cormen
# 7                                     Donald E. Knuth
# 9             Andrew S. Tanenbaum, David J. Wetherall
# 51             John G. Proakis, Dimitris G. Manolakis
# 8                  Harold Abelson, Gerald Jay Sussman
# 23                           William D. Callister Jr.
# 4                           Andrew Hunt, David Thomas
# 14               John L. Hennessy, David A. Patterson
# 42  J. Duncan Glover, Mulukutla S. Sarma, Thomas O...
#
#                         genre
# 19                 Algorithms
# 7                  Algorithms
# 9                  Networking
# 51  Digital Signal Processing
# 8                 Programming
# 23          Materials Science
# 4        Software Engineering
# 14      Computer Architecture
# 42              Power Systems

# %% [markdown]
# # Collaborative Filtering

# %% [markdown]
# recommends items based on the preferences of similar users

# %%
# Sample user interactions data
data = {
    'user_id': [1, 1, 1, 2, 2, 3, 3, 3, 3],
    'book_id': [101, 102, 103, 101, 104, 102, 103, 104, 105],
    'rating': [5, 3, 4, 4, 2, 5, 4, 3, 1],
    'borrow_count': [10, 5, 7, 2, 3, 6, 4, 1, 2]
}

user_interactions = pd.DataFrame(data)


# df = df[['book_id', 'title', 'author', 'genre']]

# Create a weighted interaction score
user_interactions['interaction_score'] = user_interactions['rating'] + user_interactions['borrow_count']

# Create a user-item matrix
user_item_matrix = user_interactions.pivot(index='user_id', columns='book_id', values='interaction_score').fillna(0)

# Convert the user-item matrix to a numpy array of floats
user_item_matrix = user_item_matrix.values.astype(float)

# Determine an appropriate value for k
num_users, num_items = user_item_matrix.shape
k = min(num_users, num_items) - 1  # k must be less than the smallest dimension

# Perform matrix factorization using SVD
U, sigma, Vt = svds(user_item_matrix, k=k)
sigma = np.diag(sigma)

# Compute predicted ratings
predicted_ratings = np.dot(np.dot(U, sigma), Vt)

# Convert predicted ratings back to a DataFrame
predicted_ratings_df = pd.DataFrame(predicted_ratings, columns=user_interactions['book_id'].unique())

# Function to get collaborative filtering recommendations
def get_collaborative_filtering_recommendations(user_id, num_recommendations=10):
    user_idx = user_id - 1  # Adjust user_id to zero-based index
    user_ratings = predicted_ratings_df.iloc[user_idx]
    sorted_indices = np.argsort(user_ratings)[::-1]
    recommended_indices = sorted_indices[:num_recommendations]
    return df[df['book_id'].isin(predicted_ratings_df.columns[recommended_indices])][['title', 'author', 'genre']]

get_collaborative_filtering_recommendations(3)
# Out:
#                                            title  \
# 100            Introduction to Quantum Mechanics
# 101                          Classical Mechanics
# 102  Modern Physics for Scientists and Engineers
# 103                 Engineering Electromagnetics
# 104      Thermodynamics: An Engineering Approach
#
#                                            author                genre
# 100      David J. Griffiths, Darrell F. Schroeter    Quantum Mechanics
# 101  Herbert Goldstein, Charles Poole, John Safko  Classical Mechanics
# 102               Stephen T. Thornton, Andrew Rex       Modern Physics
# 103                 William H. Hayt, John A. Buck     Electromagnetics
# 104             Yunus A. Çengel, Michael A. Boles       Thermodynamics

# %% [markdown]
# # Hybrid Approach

# %% [markdown]
#  both content-based and collaborative filtering methods to leverage the strengths of both alogrithm

# %%
def get_hybrid_recommendations(title, user_id, cosine_sim=cosine_sim, num_recommendations=10):
    content_based_recs = get_content_based_recommendations(title, cosine_sim)
    collaborative_recs = get_collaborative_filtering_recommendations(user_id, num_recommendations)
    
    combined_recs = pd.concat([content_based_recs, collaborative_recs]).drop_duplicates().head(num_recommendations)
    return combined_recs

# Example usage
# print(get_hybrid_recommendations('Introduction to Algorithms', 1, num_recommendations=5))

get_hybrid_recommendations('Introduction to Algorithms', 2, num_recommendations=10)
# Out:
#                                                  title  \
# 19                                 Algorithms Unlocked
# 7                      The Art of Computer Programming
# 9                                    Computer Networks
# 51   Digital Signal Processing: Principles, Algorit...
# 8    Structure and Interpretation of Computer Programs
# 100                  Introduction to Quantum Mechanics
# 101                                Classical Mechanics
# 102        Modern Physics for Scientists and Engineers
# 103                       Engineering Electromagnetics
# 104            Thermodynamics: An Engineering Approach
#
#                                            author                      genre
# 19                               Thomas H. Cormen                 Algorithms
# 7                                 Donald E. Knuth                 Algorithms
# 9         Andrew S. Tanenbaum, David J. Wetherall                 Networking
# 51         John G. Proakis, Dimitris G. Manolakis  Digital Signal Processing
# 8              Harold Abelson, Gerald Jay Sussman                Programming
# 100      David J. Griffiths, Darrell F. Schroeter          Quantum Mechanics
# 101  Herbert Goldstein, Charles Poole, John Safko        Classical Mechanics
# 102               Stephen T. Thornton, Andrew Rex             Modern Physics
# 103                 William H. Hayt, John A. Buck           Electromagnetics
# 104             Yunus A. Çengel, Michael A. Boles             Thermodynamics
